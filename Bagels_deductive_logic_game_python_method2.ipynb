# %%
def main():
    
    print("")
    print("Bagels, a deductive logic game.")
    print("")
    print("I am thinking of a 3-digit number. Try to guess what it is. Here are some clues:")
    print("")
    print("When I say:""          ""That means:")
    print("  Pico""               ""One digit is correct but in the wrong position.")
    print("  Fermi""              ""One digit is correct and in the right position.")
    print("  Bagels""             ""No digit is correct." )
    print("")
    print("I have thought up a number.")
    print("")
    print("You have 10 guesses to get it.")
      
    
    
    from random import randint
    rad_str = str(randint(100, 999))
    print("random number", rad_str)
    #rad_str = '345'
    i=1
    while i<=10:
        print("Guess#",i)
        gus_num = str(input(""))
        
        
        if len(gus_num) != 3:
            print("This is NOT a 3 digit number!")
            
        count1 = 0
        count2 = 0
        count3 = 0
        j =0
        for x in gus_num:
           #print("j", j)
            k=0
            for y in rad_str:
                #print("k", k)
                #print("gus_num", gus_num[j])
                if gus_num[j] == rad_str[k] and j == k:
                    count1 += 1
                    #print("Fermi")
                    #if count1 == 3:
                    #print("You got it!")
                        #break
                if gus_num[j] == rad_str[k] and j != k:
                    #print("Pico")
                    count2 += 1
                if gus_num[j] != rad_str[k] and j != k:
                    #print("Bagels")
                    count3 += 1
                k=k+1
            j=j+1
        #print("count1", count1)
        #print("count2", count2)
        #print("count3", count3)
    
        if count1 == 1:
            print("Fermi")
        if count1 == 2:
            print("Fermi Fermi")
        if count1 == 3:
            print("You got it!")
    
        if count2 == 1:
            print("Pico")
    
        if count2 ==2:
            print("Pico Pico")
        if count2 ==3:
            print("Pico Pico Pico")
    
        if count3 ==3:
            print("Bagels")
        
        if i == 10 or count1 == 3:
            print("Do you want to play again? (yes or no)")
            val = input("")
            if val == "yes":
                return main()
            else: 
                i= 11
                print("Thanks for playing!")
